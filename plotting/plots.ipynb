# %%
using Plots
using JSON
using LaTeXStrings

include("plotting.jl");

# %%
# read the json file
results = JSON.parsefile("results/kdv_1_soliton.json")
# Out:
# Dict{String, Any} with 3 entries:
#   "domain"   => Dict{String, Any}("t"=>Any[0.0, 0.014014, 0.028028, 0.042042, 0…
#   "losses"   => Dict{String, Any}("total"=>Any[0.142317, 0.0833492, 0.0425445, …
#   "solution" => Dict{String, Any}("u_pred"=>Any[Any[0.00023076, 0.000230581, 0.…

# %%
plot_losses(results["losses"])
