# %%
from models import KDV

from torch import nn
from matplotlib import pyplot as plt

# retina plots in matplotlib
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## **KdV**

# %% [markdown]
# ### **Single Soliton Solutions**

# %%
model = KDV(num_solitons=1, seed=1001)
losses = model.train()
# Out:
# Using device: cuda
#
# Training domain setup complete:
# - 30000 collocation points
# - 30000 initial points
# - 30000 boundary points
# Using 1-soliton initial condition.
# Starting Adam optimization...
# /home/karnav/anaconda3/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /opt/conda/conda-bld/pytorch_1729647429097/work/aten/src/ATen/cuda/CublasHandlePool.cpp:135.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Adam - Epoch 0/1000, Total Loss: 1.336433e+00
# Adam - Epoch 100/1000, Total Loss: 3.457236e-02
# Adam - Epoch 200/1000, Total Loss: 3.195604e-02
# Adam - Epoch 300/1000, Total Loss: 2.972041e-02
# Adam - Epoch 400/1000, Total Loss: 2.764244e-02
# Adam - Epoch 500/1000, Total Loss: 2.506268e-02
# Adam - Epoch 600/1000, Total Loss: 2.197825e-02
# Adam - Epoch 700/1000, Total Loss: 1.680222e-02
# Adam - Epoch 800/1000, Total Loss: 1.134524e-02
# Adam - Epoch 900/1000, Total Loss: 6.980154e-03
# Adam - Epoch 999/1000, Total Loss: 3.976187e-03
#
# Starting L-BFGS optimization...
# L-BFGS - Iteration 100, Total Loss: 2.109859e-04
# L-BFGS - Iteration 200, Total Loss: 1.142657e-04
# L-BFGS - Iteration 300, Total Loss: 5.510658e-05
# L-BFGS - Iteration 400, Total Loss: 2.901599e-05
# L-BFGS - Iteration 500, Total Loss: 1.699346e-05
# L-BFGS - Iteration 600, Total Loss: 1.058302e-05
# L-BFGS - Iteration 700, Total Loss: 6.901069e-06
# L-BFGS - Iteration 800, Total Loss: 4.857696e-06
# L-BFGS - Iteration 900, Total Loss: 3.192813e-06
# L-BFGS - Iteration 1000, Total Loss: 2.294050e-06
# L-BFGS - Iteration 1100, Total Loss: 1.645563e-06
# L-BFGS - Iteration 1200, Total Loss: 1.177368e-06
# L-BFGS - Iteration 1300, Total Loss: 9.101784e-07
# L-BFGS - Iteration 1400, Total Loss: 7.054344e-07
# L-BFGS - Iteration 1500, Total Loss: 5.692731e-07
# L-BFGS - Iteration 1600, Total Loss: 4.561331e-07
# L-BFGS - Iteration 1700, Total Loss: 3.829352e-07
# L-BFGS - Iteration 1800, Total Loss: 3.206702e-07
# L-BFGS - Iteration 1900, Total Loss: 2.407085e-07
# L-BFGS - Iteration 2000, Total Loss: 2.105520e-07
# L-BFGS - Iteration 2100, Total Loss: 1.884557e-07
# L-BFGS complete, Final Loss: 1.857686e-07

# %%
model.plot_losses(losses)

# %%
model.plot_losses(losses, component=['pde', 'initial', 'boundary', 'total'])

# %%
model.plot_spacetime()
# Out:
# Testing domain created with 1000x1000 grid points.
# Computing solutions over the test domain...
# Attempting to compute analytical solution...
# Analytical solution computed successfully.
# Test solutions computation complete.

# %%
model.plot_profiles(t_points=[0.0, 1.0, 5.0, 10.0])

# %%
model.test(plot_heatmap=True)
# Out:
# Error Metrics Summary:
#   Mean Absolute Error (MAE): 4.621570e-04
#   L2 Error: 9.422851e-04
#   Relative L2 Error: 4.781195e-03
#   Maximum Error: 1.554096e-02
