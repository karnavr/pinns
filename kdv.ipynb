# %%
from models import KDV

from torch import nn
from matplotlib import pyplot as plt

# %% [markdown]
# ## **KdV**

# %%
model = KDV(num_solitons=1)
# Out:
# Using device: cuda
#
# Domain setup complete with 30000 collocation points, 30000 initial points, and 30000 boundary points.
# Using 1-soliton initial condition.

# %%
losses = model.train()
# Out:
# Starting Adam optimization...
# /home/karnav/anaconda3/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /opt/conda/conda-bld/pytorch_1729647429097/work/aten/src/ATen/cuda/CublasHandlePool.cpp:135.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Adam - Epoch 0/1000, Total Loss: 8.121282e-01
# Adam - Epoch 100/1000, Total Loss: 3.486497e-02
# Adam - Epoch 200/1000, Total Loss: 3.231730e-02
# Adam - Epoch 300/1000, Total Loss: 3.060919e-02
# Adam - Epoch 400/1000, Total Loss: 2.914370e-02
# Adam - Epoch 500/1000, Total Loss: 2.811792e-02
# Adam - Epoch 600/1000, Total Loss: 2.712438e-02
# Adam - Epoch 700/1000, Total Loss: 2.608681e-02
# Adam - Epoch 800/1000, Total Loss: 2.497216e-02
# Adam - Epoch 900/1000, Total Loss: 2.363786e-02
# Adam - Epoch 999/1000, Total Loss: 2.172195e-02
#
# Starting L-BFGS optimization...
# L-BFGS - Iteration 100, Total Loss: 4.527836e-03
# L-BFGS - Iteration 200, Total Loss: 5.871397e-04
# L-BFGS - Iteration 300, Total Loss: 2.812001e-04
# L-BFGS - Iteration 400, Total Loss: 2.051674e-04
# L-BFGS - Iteration 500, Total Loss: 1.316451e-04
# L-BFGS - Iteration 600, Total Loss: 8.511457e-05
# L-BFGS - Iteration 700, Total Loss: 6.338488e-05
# L-BFGS - Iteration 800, Total Loss: 5.072088e-05
# L-BFGS - Iteration 900, Total Loss: 4.005112e-05
# L-BFGS - Iteration 1000, Total Loss: 2.821744e-05
# L-BFGS - Iteration 1100, Total Loss: 1.947318e-05
# L-BFGS - Iteration 1200, Total Loss: 1.245833e-05
# L-BFGS - Iteration 1300, Total Loss: 8.797515e-06
# L-BFGS - Iteration 1400, Total Loss: 6.364521e-06
# L-BFGS - Iteration 1500, Total Loss: 4.904688e-06
# L-BFGS - Iteration 1600, Total Loss: 3.820167e-06
# L-BFGS - Iteration 1700, Total Loss: 3.024987e-06
# L-BFGS - Iteration 1800, Total Loss: 2.517300e-06
# L-BFGS - Iteration 1900, Total Loss: 2.165983e-06
# L-BFGS - Iteration 2000, Total Loss: 1.875382e-06
# L-BFGS - Iteration 2100, Total Loss: 1.605663e-06
# L-BFGS - Iteration 2200, Total Loss: 1.218976e-06
# L-BFGS - Iteration 2300, Total Loss: 1.049517e-06
# L-BFGS - Iteration 2400, Total Loss: 9.411658e-07
# L-BFGS - Iteration 2500, Total Loss: 7.572422e-07
# L-BFGS - Iteration 2600, Total Loss: 6.938513e-07
# L-BFGS - Iteration 2700, Total Loss: 6.338341e-07
# L-BFGS - Iteration 2800, Total Loss: 5.795445e-07
# L-BFGS - Iteration 2900, Total Loss: 5.057448e-07
# L-BFGS - Iteration 3000, Total Loss: 4.423928e-07
# L-BFGS - Iteration 3100, Total Loss: 4.213485e-07
# L-BFGS - Iteration 3200, Total Loss: 3.782281e-07
# L-BFGS complete, Final Loss: 3.776734e-07

# %%
model.plot_losses(losses)

# %%
model.plot_losses(losses, component=['pde', 'initial', 'boundary'])

# %%
model.plot_error_heatmap()
# Out:
# Evaluating error over the entire space-time domain (200x200 points)...
# Mean Error: 2.732531e-03
# Max Error: 2.685883e-01
# (<Figure size 1000x600 with 2 Axes>,
#  <Axes: xlabel='Time (t)', ylabel='Position (x)'>)

# %%
model.plot_spacetime()

# %%
model.animate_solution("test.gif")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model.animate_solution("test.gif")
#
# File ~/Documents/pinns/models/kdv.py:641, in KDV.animate_solution(self, running_time, fps, save_path, dpi)
#     636 """
#     637 Create an animation of the solution profiles over time.
#     638 """
#     639 # This can remain the same as Burgers
#     640 # calculate the number of frames needed for the requested duration and fps
# --> 641 n_frames = int(running_time * fps)
#     643 # generate equally spaced time points over the entire time domain
#     644 t_start, t_end = self.t_lims
#
# ValueError: invalid literal for int() with base 10: 'test.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.giftest.gi

# %%
model.plot_profiles(t_points=[0.0, 1.0, 5.0, 10.0])
