# %%
from models import KDV

from torch import nn
from matplotlib import pyplot as plt

# %% [markdown]
# ## **KdV**

# %%
model = KDV(num_solitons=1)
# Out:
# Using device: cuda
#
# Domain setup complete with 30000 collocation points, 30000 initial points, and 30000 boundary points.
# Using 1-soliton initial condition.

# %%
losses = model.train()
# Out:
# Starting Adam optimization...
# /home/karnav/anaconda3/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /opt/conda/conda-bld/pytorch_1729647429097/work/aten/src/ATen/cuda/CublasHandlePool.cpp:135.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Adam - Epoch 0/1000, Total Loss: 4.472854e-02
# Adam - Epoch 100/1000, Total Loss: 3.181378e-02
# Adam - Epoch 200/1000, Total Loss: 2.909240e-02
# Adam - Epoch 300/1000, Total Loss: 2.683725e-02
# Adam - Epoch 400/1000, Total Loss: 2.312226e-02
# Adam - Epoch 500/1000, Total Loss: 1.494305e-02
# Adam - Epoch 600/1000, Total Loss: 6.237690e-03
# Adam - Epoch 700/1000, Total Loss: 2.679098e-03
# Adam - Epoch 800/1000, Total Loss: 1.151699e-03
# Adam - Epoch 900/1000, Total Loss: 6.588374e-04
# Adam - Epoch 999/1000, Total Loss: 4.634818e-04
#
# Starting L-BFGS optimization...
# L-BFGS - Iteration 100, Total Loss: 2.053997e-04
# L-BFGS - Iteration 200, Total Loss: 1.428956e-04
# L-BFGS - Iteration 300, Total Loss: 6.491734e-05
# L-BFGS - Iteration 400, Total Loss: 2.195711e-05
# L-BFGS - Iteration 500, Total Loss: 6.717508e-06
# L-BFGS - Iteration 600, Total Loss: 2.150107e-06
# L-BFGS - Iteration 700, Total Loss: 1.025460e-06
# L-BFGS - Iteration 800, Total Loss: 6.179990e-07
# L-BFGS - Iteration 900, Total Loss: 4.609060e-07
# L-BFGS - Iteration 1000, Total Loss: 3.422389e-07
# L-BFGS - Iteration 1100, Total Loss: 1.917381e-07
# L-BFGS - Iteration 1200, Total Loss: 1.372246e-07
# L-BFGS - Iteration 1300, Total Loss: 1.047191e-07
# L-BFGS complete, Final Loss: 1.041134e-07

# %%
model.plot_losses(losses)

# %%
model.plot_losses(losses, component=['pde', 'initial', 'boundary'])

# %%
model.plot_error_heatmap()
# Out:
# Evaluating error over the entire space-time domain (200x200 points)...
# Mean Error: 4.506716e-04
# Max Error: 3.253686e-02
# (<Figure size 1000x600 with 2 Axes>,
#  <Axes: xlabel='Time (t)', ylabel='Position (x)'>)

# %%
model.plot_spacetime()

# %%
model.animate_solution()

# %%
model.plot_profiles(t_points=[0.0, 1.0, 5.0, 10.0])
