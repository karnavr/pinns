# %%
from models import KDV

from torch import nn
from matplotlib import pyplot as plt

# %% [markdown]
# ## **KdV**

# %%
model = KDV(num_solitons=1)
# Out:
# Using device: cuda
#
# Domain setup complete with 30000 collocation points, 30000 initial points, and 30000 boundary points.
# Using 1-soliton initial condition.

# %%
losses = model.train()
# Out:
# Starting Adam optimization...
# /home/karnav/anaconda3/lib/python3.11/site-packages/torch/autograd/graph.py:825: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /opt/conda/conda-bld/pytorch_1729647429097/work/aten/src/ATen/cuda/CublasHandlePool.cpp:135.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Adam - Epoch 0/1000, Loss: 8.574498e-02
# Adam - Epoch 100/1000, Loss: 3.299825e-02
# Adam - Epoch 200/1000, Loss: 3.029629e-02
# Adam - Epoch 300/1000, Loss: 2.784063e-02
# Adam - Epoch 400/1000, Loss: 2.638950e-02
# Adam - Epoch 500/1000, Loss: 2.473605e-02
# Adam - Epoch 600/1000, Loss: 2.190545e-02
# Adam - Epoch 700/1000, Loss: 1.436452e-02
# Adam - Epoch 800/1000, Loss: 5.199158e-03
# Adam - Epoch 900/1000, Loss: 1.494081e-03
# Adam - Epoch 999/1000, Loss: 6.431409e-04
#
# Starting L-BFGS optimization...
# L-BFGS - Iteration 100, Loss: 1.844563e-04
# L-BFGS - Iteration 200, Loss: 8.960454e-05
# L-BFGS - Iteration 300, Loss: 4.782879e-05
# L-BFGS - Iteration 400, Loss: 1.876271e-05
# L-BFGS - Iteration 500, Loss: 7.451637e-06
# L-BFGS - Iteration 600, Loss: 3.088863e-06
# L-BFGS - Iteration 700, Loss: 1.281863e-06
# L-BFGS - Iteration 800, Loss: 8.536290e-07
# L-BFGS - Iteration 900, Loss: 5.596293e-07
# L-BFGS - Iteration 1000, Loss: 4.147784e-07
# L-BFGS - Iteration 1100, Loss: 3.334597e-07
# L-BFGS complete, Final Loss: 3.180367e-07

# %%
model.plot_losses(losses)
